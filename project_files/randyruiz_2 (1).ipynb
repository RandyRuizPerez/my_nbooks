# %% [markdown]
# # "Chapter 2 Assignment"

# %% [markdown]
# ## Randy Ruiz Perez

# %%
import pandas as pd 
ramen_ratings_url = 'ramen-ratings.csv'

# %%
ramen = pd.read_csv(ramen_ratings_url)
ramen
# Out:
#                Brand                                            Variety Style  \
# 0          New Touch                          T's Restaurant Tantanmen    Cup
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2             Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4     Ching's Secret                                    Singapore Curry  Pack
# ...              ...                                                ...   ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573         Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574         Wai Wai                                     Tom Yum Shrimp  Pack
# 2575         Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576        Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# ...

# %%
ramen.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %%
ramen.tail()
# Out:
#          Brand                                            Variety Style  \
# 2572     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573   Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574   Wai Wai                                     Tom Yum Shrimp  Pack
# 2575   Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576  Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# 2572   Vietnam    3.5
# 2573  Thailand    1.0
# 2574  Thailand    2.0
# 2575  Thailand    2.0
# 2576       USA    0.5

# %%
ramen.describe(include='all')
# Out:
#          Brand Variety Style Country        Stars
# count     2577    2577  2575    2577  2577.000000
# unique     355    2410     7      38          NaN
# top     Nissin    Beef  Pack   Japan          NaN
# freq       381       7  1528     352          NaN
# mean       NaN     NaN   NaN     NaN     3.654676
# std        NaN     NaN   NaN     NaN     1.015331
# min        NaN     NaN   NaN     NaN     0.000000
# 25%        NaN     NaN   NaN     NaN     3.250000
# 50%        NaN     NaN   NaN     NaN     3.750000
# 75%        NaN     NaN   NaN     NaN     4.250000
# max        NaN     NaN   NaN     NaN     5.000000

# %%
ramen.nunique()
# Out:
# Brand       355
# Variety    2410
# Style         7
# Country      38
# Stars        42
# dtype: int64

# %%
vietnam = ramen[ramen['Country'] == 'Vietnam']
vietnam
# Out:
#               Brand                                            Variety Style  \
# 18         Binh Tay                                         Mi Hai Cua  Pack
# 52    Uni-President                                    Mushroom Flavor  Pack
# 143        Mum Ngon                                   Lau Tom Chua Cay  Pack
# 224           Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
# 365         Acecook                             Oh! Ricey Pork Flavour  Pack
# ...             ...                                                ...   ...
# 2486       Binh Tay                                   Mi Chay Mushroom  Pack
# 2535        Ve Wong                             Kung-Fu Chicken Flavor  Pack
# 2570        Ve Wong                                      Mushroom Pork  Pack
# 2571          Vifon                                           Nam Vang  Pack
# 2572          Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
#
#       Country  Stars
# 18    Vietnam   4.00
# ...

# %%
ramen[['Brand', 'Style']]
# Out:
#                Brand Style
# 0          New Touch   Cup
# 1           Just Way  Pack
# 2             Nissin   Cup
# 3            Wei Lih  Pack
# 4     Ching's Secret  Pack
# ...              ...   ...
# 2572           Vifon  Bowl
# 2573         Wai Wai  Pack
# 2574         Wai Wai  Pack
# 2575         Wai Wai  Pack
# 2576        Westbrae  Pack
#
# [2577 rows x 2 columns]

# %%
ramen[['Country']]
# Out:
#        Country
# 0        Japan
# 1       Taiwan
# 2          USA
# 3       Taiwan
# 4        India
# ...        ...
# 2572   Vietnam
# 2573  Thailand
# 2574  Thailand
# 2575  Thailand
# 2576       USA
#
# [2577 rows x 1 columns]

# %%
sort_ramen = ramen.sort_values(by='Stars', ascending=False)
sort_ramen
# Out:
#                Brand                                            Variety Style  \
# 1585     Prima Taste                            Singapore Laksa La Mian  Pack
# 446         Maruchan  Instant Lunch Chipotle Chicken Flavor Ramen No...   Cup
# 484         Nongshim          Champong Noodle Soup Spicy Seafood Flavor  Pack
# 483           Nissin                              Straits Kitchen Laksa  Pack
# 1613          Nissin                 Raoh Backfat Rich Soy Sauce Flavor  Bowl
# ...              ...                                                ...   ...
# 522             Koyo                 Garlic Pepper Reduced Sodium Ramen  Pack
# 561    Samyang Foods                            Honey & Cheese Big Bowl  Bowl
# 950            Azami                                Kimchee Noodle Soup   Cup
# 2079  Hsin Tung Yang                     Tiny Noodle With Oyster Flavor  Pack
# 52     Uni-President                                    Mushroom Flavor  Pack
#
#           Country  Stars
# ...

# %%
ramen['Country'] = ramen['Country'].replace('USA', 'United States')

# %%
ramen.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#          Country  Stars
# 0          Japan   3.75
# 1         Taiwan   1.00
# 2  United States   2.25
# 3         Taiwan   2.75
# 4          India   3.75

# %%
num_countries = [ramen['Country'].unique()]
num_countries
# Out:
# [array(['Japan', 'Taiwan', 'United States', 'India', 'South Korea',
#         'Singapore', 'Thailand', 'Hong Kong', 'Vietnam', 'Ghana',
#         'Malaysia', 'Indonesia', 'China', 'Nigeria', 'Germany', 'Hungary',
#         'Mexico', 'Fiji', 'Australia', 'Pakistan', 'Bangladesh', 'Canada',
#         'Nepal', 'Brazil', 'UK', 'Myanmar', 'Netherlands', 'Cambodia',
#         'Finland', 'Sarawak', 'Philippines', 'Sweden', 'Colombia',
#         'Estonia', 'Holland', 'Poland', 'Dubai'], dtype=object)]

# %%
countries_ratings = ramen.groupby('Country')['Stars'].mean()
top_countries = countries_ratings.sort_values(ascending=False).head(3)
top_avg = top_countries.reset_index()
top_avg
# Out:
#     Country     Stars
# 0    Brazil  4.350000
# 1   Sarawak  4.333333
# 2  Cambodia  4.200000

# %%
countries_ratings = ramen.groupby('Country')['Stars'].mean()
bottom_countries = countries_ratings.sort_values(ascending=True).head(3)
bottom_avg = bottom_countries.reset_index()
bottom_avg
# Out:
#        Country     Stars
# 0      Nigeria  1.500000
# 1       Canada  2.243902
# 2  Netherlands  2.483333

# %%
# %%time
ountries_ratings = ramen.groupby('Country')['Stars'].mean()
bottom_countries = countries_ratings.sort_values(ascending=True).head(3)
bottom_avg = bottom_countries.reset_index()
bottom_avg
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
#        Country     Stars
# 0      Nigeria  1.500000
# 1       Canada  2.243902
# 2  Netherlands  2.483333
